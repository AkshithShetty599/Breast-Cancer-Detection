# %%
import pandas as pd

df = pd.read_csv(r"/content/drive/MyDrive/Colab Notebooks/Breast Cancer Detection/Data/data.csv")

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
df = df.drop(['id','Unnamed: 32'],axis=1)

# %%
df.columns
# Out:
# Index(['diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
df['diagnosis'].value_counts()
# Out:
# diagnosis
# B    357
# M    212
# Name: count, dtype: int64

# %%
df['diagnosis'] = df['diagnosis'].map({'B':0,'M':1})

# %%
df['diagnosis'].value_counts()
# Out:
# diagnosis
# 0    357
# 1    212
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split

features = [
            'radius_mean',
            'texture_mean',
            'perimeter_mean',
            'area_mean',
            'smoothness_mean',
            'compactness_mean',
            'concavity_mean',
            'concave points_mean',
            'symmetry_mean',
            'fractal_dimension_mean',
            'radius_se',
            'texture_se',
            'perimeter_se',
            'area_se',
            'smoothness_se',
            'compactness_se',
            'concavity_se',
            'concave points_se',
            'symmetry_se',
            'fractal_dimension_se',
            'radius_worst',
            'texture_worst',
            'perimeter_worst',
            'area_worst',
            'smoothness_worst',
            'compactness_worst',
            'concavity_worst',
            'concave points_worst',
            'symmetry_worst',
            'fractal_dimension_worst'
            ]
target = 'diagnosis'

X = df[features]
y = df[target]

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2023)

# %%
from sklearn.ensemble import GradientBoostingClassifier

gbm_untuned = GradientBoostingClassifier(random_state=2023)

gbm_untuned.fit(X_train,y_train)

print(f"Training Accuracy : {gbm_untuned.score(X_train,y_train)}")
print(f"Test Accuracy : {gbm_untuned.score(X_test,y_test)}")
# Out:
# Training Accuracy : 1.0
# Test Accuracy : 0.9736842105263158

# %%
from sklearn.metrics import confusion_matrix

confusion_matrix(y_test,gbm_untuned.predict(X_test))
# Out:
# array([[70,  1],
#        [ 2, 41]])

# %%
from sklearn.metrics import classification_report

print("\nClassification Report:\n", classification_report(y_test, gbm_untuned.predict(X_test)))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98        71
#            1       0.98      0.95      0.96        43
#
#     accuracy                           0.97       114
#    macro avg       0.97      0.97      0.97       114
# weighted avg       0.97      0.97      0.97       114

# %%
import numpy as np
from sklearn.model_selection import RandomizedSearchCV
from sklearn.ensemble import GradientBoostingClassifier

gb = GradientBoostingClassifier(random_state=2023)

params = {
    'n_estimators': [100, 300, 500],  # smaller range
    'learning_rate': [0.01, 0.1],     # most impactful values
    'max_features': [None, "sqrt"],
    'subsample': [0.9, 1.0],          # fewer options
    'max_depth': [3, 5, 7],           # avoid deeper trees
    'min_samples_leaf': [2, 5]        # reduced options
}

grid = RandomizedSearchCV(
    gb,
    params,
    n_iter=30,
    scoring="recall",
    n_jobs=-1
)

grid.fit(X_train, y_train)

grid.best_params_
# Out:
# {'subsample': 0.9,
#  'n_estimators': 500,
#  'min_samples_leaf': 2,
#  'max_features': 'sqrt',
#  'max_depth': 7,
#  'learning_rate': 0.1}

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import GridSearchCV

# Best parameters from RandomizedSearchCV
best_params = {
    'subsample': [0.8,0.9],
    'n_estimators': [300],
    'min_samples_leaf': [1,2],
    'max_features': [None],
    'max_depth': [1,2,3],
    'learning_rate': [0.1]
}

# Define the model
gb = GradientBoostingClassifier(random_state=2023)

# GridSearchCV for confirmation + refit
grid = GridSearchCV(
    gb,
    best_params,
    scoring='recall',
    cv=5,
    n_jobs=-1
)

# Fit the grid search
grid.fit(X_train, y_train)

# Best model (already trained)
best_model = grid.best_estimator_

# Optional: Evaluate
y_pred = best_model.predict(X_test)

from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97        71
#            1       1.00      0.91      0.95        43
#
#     accuracy                           0.96       114
#    macro avg       0.97      0.95      0.96       114
# weighted avg       0.97      0.96      0.96       114

# %%
import pickle
with open("model.pkl", "wb") as f:
    pickle.dump(best_model, f)

# %%
from google.colab import files
files.download("model.pkl")
